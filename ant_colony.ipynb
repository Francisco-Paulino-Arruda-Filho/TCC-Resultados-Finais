# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union, Optional
import csv

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    ant_index: int,
    best_cost: float,
    current_cost: float,
    tempo_inicio_global: float
) -> None:
    """
    Salva resultados parciais da execução do ACO em um arquivo CSV no mesmo diretório.
    """
    path = file_name  

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido"
    ]
    write_header = not os.path.exists(path)

    with open(path, mode="a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(header)
        writer.writerow([
            instancia,
            ant_index,
            best_cost,
            current_cost,
            round(time.time() - tempo_inicio_global, 3)
        ])

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None
) -> Tuple[List[int], int]:
    """
    Algoritmo de Otimização por Colônia de Formigas (ACO) puro com salvamento de resultados.
    """

    n: int = len(fluxo)
    heuristica: np.ndarray = 1 / (np.array(distancia) + 1e-10)
    feromonio: np.ndarray = inicializar_feromonio(n)

    melhor_solucao: Optional[List[int]] = None
    melhor_custo: float = float("inf")
    file_name = f"Resultados/iteracoes_{instancia}_ACO.csv"


    if tempo_inicio_global and tempo_global_max:
        if (time.time() - tempo_inicio_global) > tempo_global_max:
            return melhor_solucao if melhor_solucao else [], int(melhor_custo)

        solucoes: List[List[int]] = []
        custos: List[int] = []

        for j in range(n_formigas):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

            s: List[int] = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo: int = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                ant_index=j,
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_inicio_global=tempo_inicio_global or time.time()
            )

        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            ant_index=-1,  
            best_cost=melhor_custo,
            current_cost=min(custos),
            tempo_inicio_global=tempo_inicio_global or time.time()
        )

    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("Instancias/*.txt")

    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]

        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        rho_values = [0.02, 0.05, 0.2]  

        for seed in range(42, 52):

            tempo_decorrido_global = time.time() - tempo_inicio_instancia
            if tempo_decorrido_global >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            random.seed(seed)
            np.random.seed(seed)

            for rho in rho_values: 

                process = psutil.Process(os.getpid())
                tempo_inicio_seed = time.time()

                parametros = {
                    "n_formigas": 10,
                    "alpha": 1.0,
                    "beta": 2.0,
                    "rho": rho,
                    "Q": 1,
                }

                melhor_solucao, melhor_custo = aco_qap(
                    fluxo=matriz_fluxo,
                    distancia=matriz_distancia,
                    instancia=nome_instancia,
                    tempo_inicio_global=tempo_inicio_instancia,
                    tempo_global_max=tempo_global_max,
                    **parametros
                )

                tempo_fim_seed = time.time()

                tempo_restante_global = max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
                tempo_execucao = min(tempo_fim_seed - tempo_inicio_seed, tempo_restante_global)

                try:
                    memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
                except AttributeError:
                    memoria_usada = process.memory_info().rss / (1024 * 1024)

                resultados.append({
                    "instancia": nome_instancia,
                    "seed": seed,
                    "rho": rho,  
                    "melhor_solucao": melhor_solucao,
                    "custo": melhor_custo,
                    "tempo_execucao_segundos": round(tempo_execucao, 2),
                    "memoria_usada_MB": round(memoria_usada, 2),
                    **parametros
                })

                print(
                    f"[{nome_instancia}] Seed {seed} | rho={rho} finalizada. "
                    f"Custo: {melhor_custo} | Memória: {round(memoria_usada, 2)} MB"
                )

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"Resultados/resultados_{nome_instancia}_ACO_10min.csv", index=False)

        print(f"\nResultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO_10min.csv")
# Out:
# [Bur26a] Seed 42 finalizada. Custo: 5909792 | Memória usada: 120.26 MB
# [Bur26a] Seed 43 finalizada. Custo: 5880902 | Memória usada: 120.26 MB
# [Bur26a] Seed 44 finalizada. Custo: 5948814 | Memória usada: 120.26 MB
# [Bur26a] Seed 45 finalizada. Custo: 5753451 | Memória usada: 120.26 MB
# [Bur26a] Seed 46 finalizada. Custo: 5826164 | Memória usada: 120.26 MB
# [Bur26a] Seed 47 finalizada. Custo: 5818392 | Memória usada: 120.26 MB
# [Bur26a] Seed 48 finalizada. Custo: 5923805 | Memória usada: 120.26 MB
# [Bur26a] Seed 49 finalizada. Custo: 5806977 | Memória usada: 120.26 MB
# [Bur26a] Seed 50 finalizada. Custo: 5856623 | Memória usada: 120.26 MB
# [Bur26a] Seed 51 finalizada. Custo: 5771269 | Memória usada: 120.26 MB
#
# Resultados da instância Bur26a salvos em resultados_Bur26a_ACO.csv
# [Bur26b] Seed 42 finalizada. Custo: 4156581 | Memória usada: 120.75 MB
# [Bur26b] Seed 43 finalizada. Custo: 4145257 | Memória usada: 120.75 MB
# [Bur26b] Seed 44 finalizada. Custo: 4167740 | Memória usada: 120.75 MB
# [Bur26b] Seed 45 finalizada. Custo: 4045846 | Memória usada: 120.75 MB
# [Bur26b] Seed 46 finalizada. Custo: 4115301 | Memória usada: 120.75 MB
# [Bur26b] Seed 47 finalizada. Custo: 4096136 | Memória usada: 120.75 MB
# [Bur26b] Seed 48 finalizada. Custo: 4139965 | Memória usada: 120.75 MB
# [Bur26b] Seed 49 finalizada. Custo: 4074148 | Memória usada: 120.75 MB
# [Chr18b] Seed 43 finalizada. Custo: 3076 | Memória usada: 120.87 MB
# [Chr18b] Seed 44 finalizada. Custo: 2676 | Memória usada: 120.87 MB
# [Chr18b] Seed 45 finalizada. Custo: 3128 | Memória usada: 120.87 MB
# [Chr18b] Seed 46 finalizada. Custo: 3320 | Memória usada: 120.87 MB
# [Chr18b] Seed 47 finalizada. Custo: 2958 | Memória usada: 120.87 MB
# [Chr18b] Seed 48 finalizada. Custo: 3476 | Memória usada: 120.87 MB
# [Chr18b] Seed 49 finalizada. Custo: 3184 | Memória usada: 120.88 MB
# [Chr18b] Seed 50 finalizada. Custo: 3180 | Memória usada: 120.88 MB
# [Chr18b] Seed 51 finalizada. Custo: 2788 | Memória usada: 120.88 MB
#
# Resultados da instância Chr18b salvos em resultados_Chr18b_ACO.csv
# [Chr20a] Seed 42 finalizada. Custo: 8272 | Memória usada: 120.88 MB
# [Chr20a] Seed 43 finalizada. Custo: 8180 | Memória usada: 120.88 MB
# [Chr20a] Seed 44 finalizada. Custo: 8288 | Memória usada: 120.88 MB
# [Chr20a] Seed 45 finalizada. Custo: 8978 | Memória usada: 120.88 MB
# [Chr20a] Seed 46 finalizada. Custo: 8674 | Memória usada: 120.88 MB
# [Chr20a] Seed 47 finalizada. Custo: 8342 | Memória usada: 120.88 MB
# [Chr20a] Seed 48 finalizada. Custo: 8842 | Memória usada: 120.88 MB
# [Chr20a] Seed 49 finalizada. Custo: 9554 | Memória usada: 120.88 MB
# [Chr20a] Seed 50 finalizada. Custo: 8336 | Memória usada: 120.88 MB
# [Chr20a] Seed 51 finalizada. Custo: 8402 | Memória usada: 120.88 MB
#
# Resultados da instância Chr20a salvos em resultados_Chr20a_ACO.csv
# [Chr20b] Seed 42 finalizada. Custo: 9026 | Memória usada: 120.88 MB
# [Chr20b] Seed 43 finalizada. Custo: 7930 | Memória usada: 120.88 MB
# [Chr20b] Seed 44 finalizada. Custo: 9154 | Memória usada: 120.88 MB
# [Chr20b] Seed 45 finalizada. Custo: 9596 | Memória usada: 120.88 MB
# [Chr20b] Seed 46 finalizada. Custo: 10258 | Memória usada: 120.88 MB
# [Chr20b] Seed 47 finalizada. Custo: 10008 | Memória usada: 120.88 MB
# [Chr20b] Seed 48 finalizada. Custo: 9154 | Memória usada: 120.88 MB
# [Chr20b] Seed 49 finalizada. Custo: 8254 | Memória usada: 120.88 MB
# [Chr20b] Seed 50 finalizada. Custo: 8514 | Memória usada: 120.88 MB
# [Chr20b] Seed 51 finalizada. Custo: 8942 | Memória usada: 120.88 MB
#
# Resultados da instância Chr20b salvos em resultados_Chr20b_ACO.csv
# [Chr20c] Seed 42 finalizada. Custo: 91670 | Memória usada: 120.88 MB
# [Chr20c] Seed 43 finalizada. Custo: 90006 | Memória usada: 120.88 MB
# [Chr20c] Seed 44 finalizada. Custo: 94570 | Memória usada: 120.88 MB
# [Chr20c] Seed 45 finalizada. Custo: 74064 | Memória usada: 120.88 MB
# [Chr20c] Seed 46 finalizada. Custo: 85278 | Memória usada: 120.88 MB
| Memória usada: 121.93 MB
#
# Resultados da instância Esc16g salvos em resultados_Esc16g_ACO.csv
# [Esc16h] Seed 42 finalizada. Custo: 1080 | Memória usada: 121.93 MB
# [Esc16h] Seed 43 finalizada. Custo: 1016 | Memória usada: 121.93 MB
# [Esc16h] Seed 44 finalizada. Custo: 1056 | Memória usada: 121.93 MB
# [Esc16h] Seed 45 finalizada. Custo: 1012 | Memória usada: 121.93 MB
# [Esc16h] Seed 46 finalizada. Custo: 1076 | Memória usada: 121.93 MB
# [Esc16h] Seed 47 finalizada. Custo: 1072 | Memória usada: 121.93 MB
# [Esc16h] Seed 48 finalizada. Custo: 1056 | Memória usada: 121.93 MB
# [Esc16h] Seed 49 finalizada. Custo: 1116 | Memória usada: 121.93 MB
# [Esc16h] Seed 50 finalizada. Custo: 996 | Memória usada: 121.93 MB
# [Esc16h] Seed 51 finalizada. Custo: 1050 | Memória usada: 121.93 MB
#
# Resultados da instância Esc16h salvos em resultados_Esc16h_ACO.csv
# [Esc16i] Seed 42 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 43 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 44 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 45 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 46 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 47 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 48 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 49 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 50 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Esc16i] Seed 51 finalizada. Custo: 14 | Memória usada: 121.93 MB
#
# Resultados da instância Esc16i salvos em resultados_Esc16i_ACO.csv
# [Esc16j] Seed 42 finalizada. Custo: 22 | Memória usada: 121.93 MB
# [Esc16j] Seed 43 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 44 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 45 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 46 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 47 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 48 finalizada. Custo: 22 | Memória usada: 121.93 MB
# [Esc16j] Seed 49 finalizada. Custo: 16 | Memória usada: 121.93 MB
# [Esc16j] Seed 50 finalizada. Custo: 18 | Memória usada: 121.93 MB
# [Esc16j] Seed 51 finalizada. Custo: 18 | Memória usada: 121.93 MB
#
# Resultados da instância Esc16j salvos em resultados_Esc16j_ACO.csv
# [Esc32a] Seed 42 finalizada. Custo: 370 | Memória usada: 121.93 MB
# [Esc32a] Seed 43 finalizada. Custo: 366 | Memória usada: 121.93 MB
# [Esc32a] Seed 44 finalizada. Custo: 382 | Memória usada: 121.93 MB
# [Esc32a] Seed 45 finalizada. Custo: 378 | Memória usada: 121.93 MB
# [Esc32a] Seed 46 finalizada. Custo: 370 | Memória usada: 121.93 MB
# [Esc32a] Seed 47 finalizada. Custo: 318 | Memória usada: 121.93 MB
# [Esc32a] Seed 48 finalizada. Custo: 378 | Memória usada: 121.93 MB
# [Esc32a] Seed 49 finalizada. Custo: 342 | Memória usada: 121.93 MB
# [Esc32a] Seed 50 finalizada. Custo: 390 | Memória usada: 121.93 MB
# [Esc32a] Seed 51 finalizada. Custo: 394 | Memória usada: 121.93 MB
#
# Resultados da instância Esc32a salvos em resultados_Esc32a_ACO.csv
# [Esc32b] Seed 42 finalizada. Custo: 348 | Memória usada: 121.93 MB
# [Esc32b] Seed 43 finalizada. Custo: 328 | Memória usada: 121.93 MB
# [Esc32b] Seed 44 finalizada. Custo: 324 | Memória usada: 121.93 MB
# [Esc32b] Seed 45 finalizada. Custo: 340 | Memória usada: 121.93 MB
# [Esc32b] Seed 46 finalizada. Custo: 324 | Memória usada: 121.93 MB
# [Esc32b] Seed 47 finalizada. Custo: 324 | Memória usada: 121.93 MB
# [Esc32b] Seed 48 finalizada. Custo: 324 | Memória usada: 121.93 MB
# [Esc32b] Seed 49 finalizada. Custo: 332 | Memória usada: 121.93 MB
# [Esc32b] Seed 50 finalizada. Custo: 320 | Memória usada: 121.93 MB
# [Esc32b] Seed 51 finalizada. Custo: 336 | Memória usada: 121.93 MB
#
# Resultados da instância Esc32b salvos em resultados_Esc32b_ACO.csv
# [Esc32c] Seed 42 finalizada. Custo: 786 | Memória usada: 121.93 MB
# [Esc32c] Seed 43 finalizada. Custo: 750 | Memória usada: 121.93 MB
# [Esc32c] Seed 44 finalizada. Custo: 738 | Memória usada: 121.93 MB
# [Esc32c] Seed 45 finalizada. Custo: 782 | Memória usada: 121.93 MB
# [Esc32c] Seed 46 finalizada. Custo: 750 | Memória usada: 121.93 MB
# [Esc32c] Seed 47 finalizada. Custo: 806 | Memória usada: 121.93 MB
# [Esc32c] Seed 48 finalizada. Custo: 766 | Memória usada: 121.93 MB
# [Esc32c] Seed 49 finalizada. Custo: 758 | Memória usada: 121.93 MB
# [Esc32c] Seed 50 finalizada. Custo: 766 | Memória usada: 121.93 MB
# [Esc32c] Seed 51 finalizada. Custo: 722 | Memória usada: 121.93 MB
#
# Resultados da instância Esc32c salvos em resultados_Esc32c_ACO.csv
# [Esc32d] Seed 42 finalizada. Custo: 300 | Memória usada: 121.93 MB
# [Esc32d] Seed 43 finalizada. Custo: 312 | Memória usada: 121.93 MB
# [Esc32d] Seed 44 finalizada. Custo: 276 | Memória usada: 121.93 MB
# [Esc32d] Seed 45 finalizada. Custo: 296 | Memória usada: 121.93 MB
# [Esc32d] Seed 46 finalizada. Custo: 300 | Memória usada: 121.93 MB
# [Esc32d] Seed 47 finalizada. Custo: 316 | Memória usada: 121.93 MB
# [Esc32d] Seed 48 finalizada. Custo: 292 | Memória usada: 121.93 MB
# [Esc32d] Seed 49 finalizada. Custo: 272 | Memória usada: 121.93 MB
# [Esc32d] Seed 50 finalizada. Custo: 304 | Memória usada: 121.93 MB
# [Esc32d] Seed 51 finalizada. Custo: 300 | Memória usada: 121.93 MB
#
# Resultados da instância Esc32d salvos em resultados_Esc32d_ACO.csv
# [Esc32e] Seed 42 finalizada. Custo: 24 | Memória usada: 121.93 MB
# [Esc32e] Seed 43 finalizada. Custo: 28 | Memória usada: 121.93 MB
# [Esc32e] Seed 44 finalizada. Custo: 32 | Memória usada: 121.93 MB
# [Esc32e] Seed 45 finalizada. Custo: 32 | Memória usada: 121.93 MB
# [Esc32e] Seed 46 finalizada. Custo: 32 | Memória usada: 121.93 MB
# [Esc32e] Seed 47 finalizada. Custo: 32 | Memória usada: 121.93 MB
# [Esc32e] Seed 48 finalizada. Custo: 32 | Memória usada: 121.93 MB
# [Esc32e] Seed 49 finalizada. Custo: 20 | Memória usada: 121.93 MB
# [Esc32e] Seed 50 finalizada. Custo: 24 | Memória usada: 121.93 MB
# [Esc32e] Seed 51 finalizada. Custo: 24 | Memória usada: 121.93 MB
#
# Resultados da instância Esc32e salvos em resultados_Esc32e_ACO.csv
# [Esc32g] Seed 42 finalizada. Custo: 14 | Memória usada: 121.93 MB
# [Es